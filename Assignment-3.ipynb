# %% [markdown]
# **Assignment-3**
# - Write below basic codes using eval and input also apply round wherever required

# %%
# wap ask the user take two number print subtraction multiplication and division
# ans: the subtraction of 100 and 200 is -100
#      the multiplication of 100 and 200 is 20000
#      the division of 100 and 200 is 0.5

a=eval(input('enter value:'))
b=eval(input('enter value:'))
sub=round((a-b),2)
mul=round((a*b),2)
div=round((a/b),2)
print(f'the sub of {a} and {b} is: {sub}')
print(f'the mult of {a} and {b} is: {mul}')
print(f'the divi of {a} and {b} is: {div}')
# Out:
# enter value: 100
# enter value: 200
# the sub of 100 and 200 is: -100
# the mult of 100 and 200 is: 20000
# the divi of 100 and 200 is: 0.5

# %%
# wap ask the user take the radius find the area of circle
    # pi=3.14
    # r=100
   # area_of_circle=pi*r*r

pi=3.14
r=eval(input('Enter the no:'))
area_of_circle=pi*r*r
n1=round(area_of_circle,4)
print(f'area of circle: {pi}*{r}*{r} = {n1}')
# Out:
# Enter the no: 232332
# area of circle: 3.14*232332*232332 = 169491416823.36

# %%
# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h

b=eval(input('enter the No:'))
h=eval(input('enter the No:'))
area_of_traingle=round(0.5 * b * h, 2)
print(f'area of traingle: 0.5*{b}*{h} = {area_of_traingle}')
# Out:
# enter the No: 35.252
# enter the No: 2525352
# area of traingle: 0.5*35.252*2525352 = 44511854.35

# %%
#wap ask the user take 3 numbers find the average
a=eval(input('enter value:'))
b=eval(input('enter value:'))
c=eval(input('enter value:'))
avg=(a+b+c)/3
avg1=round(avg,5)
print(f'average: {a}+{b}+{c} = {avg1}')
# Out:
# enter value: 2
# enter value: 2
# enter value: 2
# average: 2+2+2 = 2.0

# %%
# wap ask the user take the bill amount and tip amount calculate total bill
bill_amount=eval(input('Enter the no:'))
tip_amount=eval(input('Enter the no:'))
total=round((bill_amount+tip_amount),3)
print(f'Total amount: {bill_amount}+{tip_amount} = {total}')
# Out:
# Enter the no: 128125.2112
# Enter the no: 233.2332323
# Total amount: 128125.2112+233.2332323 = 128358.444

# %%
# wap ask the user take the salary, percetage of tax calculate tax amount
#      tax_amount= salary*tax_per/100
salary=eval(input('Enter the no:'))
tax_per=eval(input('Enter the no:'))
tax_amount= salary*tax_per/100
tax1=round(tax_amount,2)
print(f'total: {salary} * {tax_per} / 100 = {tax1}')
# Out:
# Enter the no: 2523.2352
# Enter the no: 23522223
# total: 2523.2352 * 23522223 / 100 = 593521010.56

# %%
# wap ask the user take the value in dollar convert into rupees
#         1$=80rs

dollar=eval(input('Enter the no:'))
rupees = round((dollar * 80),3)
print(f'{dollar} *80 convert into = {rupees}')
# Out:
# Enter the no: 23525.23322
# 23525.23322 *80 convert into = 1882018.658

# %%
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds

kg=eval(input('Enter the no:'))
pounds=round((kg*2.2),3)
print(f'total: {kg}*2.2 = {pounds}')
# Out:
# Enter the no: 2222
# total: 2222*2.2 = 4888.4
