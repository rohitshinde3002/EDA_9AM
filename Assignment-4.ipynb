# %% [markdown]
# # Assignment-4: Packages understanding

# %% [markdown]
# Execute each and every package and methods
#
# 1. random
#  randint
# random
# choice
# sample
# seed
#
# 2.Math
# sqrt
# pow
# pi
# e
#
# 3.time
# sleep
# time
#
# 4.keywords
# kwlist
#
# 5.os
# getcwd
# makdirs
#
# 6.Date
#   today date

# %% [markdown]
# # 1.   Random
# - random
# - randint
# - random
# - choice
# - sample
# - seed

# %%
import random
random.random()
# Out:
# 0.5000604945006619

# %%
import random
random.randint(1,10)
# Out:
# 2

# %%
import random
random.random()
# Out:
# 0.6094051003128352

# %%
l=[10,20,30,40,50,60,70,80]
import random
random.choice(l)
# Out:
# 50

# %%
import random
random.sample(l, 3)
# Out:
# [30, 40, 10]

# %%
import random
random.seed(10)
print(random.random())
# Out:
# 0.5714025946899135

# %% [markdown]
# # 2.Math
# - sqrt
# - pow
# - pi
# - e

# %%
l=[1,2,3,4,5,6]
import math
math.e
# Out:
# 2.718281828459045

# %%
l=[1,2,3,4,5,6]
import math
math.pi
# Out:
# 3.141592653589793

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %%
import math
math.sqrt(36)
# Out:
# 6.0

# %% [markdown]
# # 3.time
# - sleep
# - time

# %%
import time
time.sleep(3)
print('Hi sir...!')
# Out:
# Hi sir...!

# %%
import time
time.time()
# Out:
# 1763733764.5731642

# %% [markdown]
# # 4.keywords
# - kwlist

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# # 5.os
# - getcwd
# - makdirs

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\rohan shinde\\OneDrive\\Documents\\Batch18-Nov\\Assignment'

# %%
import os
os.makedirs('rohit')

# %% [markdown]
# # 6.Date
# -  today date

# %%
import datetime
x = datetime.datetime.now()
print(x)
# Out:
# 2025-11-21 19:50:08.490521
